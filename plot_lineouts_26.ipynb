# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from TS_aux import select_shots
import pandas as pd
import xarray as xr
from dataclasses import dataclass
from datetime import date
import numpy as np
import matplotlib.pyplot as plt

baseDir = Path().resolve().parent
folder_path = baseDir/"Kinshock"/"Kinshock-26A"/"tsadar fits"
data = select_shots(folder_path)
# Out:
# Stuff in folder :
#
# [0] 117827
#
# [1] 117828
#
# [2] 117830
#
# [3] 117837
#
# [4] 117838
#
# [5] 117839
#
# Files for shot 117837 :
#
# [0] 117837-12
# [1] 117837-13
# [2] 117837-5
# [3] 117837-8
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 68, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 375.8 376.1 376.4 ... 657.9 658.2
#   * Radius (\mum)  (Radius (\mum)) float64 544B -897.8 -877.2 ... 749.0 774.6
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 557kB ...
#     data           (Radius (\mum), Wavelength) float64 557kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 68, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 375.8 376.1 376.4 ... 657.9 658.2
#   * Radius (\mum)  (Radius (\mum)) float64 544B -897.8 -877.2 ... 749.0 774.6
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 557kB ...
#     data           (Radius (\mum), Wavelength) float64 557kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv
# Files for shot 117838 :
#
# [0] 117838-10
# [1] 117838-7
# [2] 117838-8
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 72, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 375.8 376.1 376.4 ... 657.9 658.2
#   * Radius (\mum)  (Radius (\mum)) float64 576B -897.8 -877.2 ... 851.6 877.2
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 590kB ...
#     data           (Radius (\mum), Wavelength) float64 590kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 72, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 375.8 376.1 376.4 ... 657.9 658.2
#   * Radius (\mum)  (Radius (\mum)) float64 576B -897.8 -877.2 ... 851.6 877.2
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 590kB ...
#     data           (Radius (\mum), Wavelength) float64 590kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 72, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 375.8 376.1 376.4 ... 657.9 658.2
#   * Radius (\mum)  (Radius (\mum)) float64 576B -897.8 -877.2 ... 851.6 877.2
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 590kB ...
#     data           (Radius (\mum), Wavelength) float64 590kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv
# Files for shot 117839 :
#
# [0] 117839-9
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 68, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 375.8 376.1 376.4 ... 657.9 658.2
#   * Radius (\mum)  (Radius (\mum)) float64 544B -897.8 -877.2 ... 749.0 774.6
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 557kB ...
#     data           (Radius (\mum), Wavelength) float64 557kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv

# %%
### PLOT 117830 ELECTRONS ###
# %reload_ext autoreload
# %autoreload 2
from plot_117830_EPW import plot_117830_EPW
plot_117830_EPW(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       3 get_ipython().run_line_magic('autoreload', '2')
#       4 from plot_117830_EPW import plot_117830_EPW
# ----> 5 plot_117830_EPW(data)
#
# File \\profiles\Users$\sban\Documents\Scripts\plot_117830_EPW.py:13, in plot_117830_EPW(data)
#      12 def plot_117830_EPW(data):
# ---> 13     lp = data['117830']['learned_parameters (1).csv']
#      14     r = shot_data.loc[117830,"pointing"] - lp["Radius (\\mum)"]/10**3
#      15     bv = (r*10**2)/shot_data.loc[117830,"timing"]
#
# KeyError: '117830'

# %%
### PLOT LOSS ###
# %reload_ext autoreload
# %autoreload 2
from plot_117837_EPW import plot_117837_EPW_loss
from plot_117837_EPW import plot_117837_EPW
plot_117837_EPW(data['117837']['117837-13'])
#plot_117837_EPW_loss(data['117837'])

# %%
### PLOT LOSS ###
# %reload_ext autoreload
# %autoreload 2
from plot_117838_EPW import plot_117838_EPW_loss
from plot_117838_EPW import plot_117838_EPW
plot_117838_EPW(data['117838']['117838-8'])
#plot_117838_EPW_loss(data['117838'])

# %%
### PLOT LOSS ###
# %reload_ext autoreload
# %autoreload 2
from plot_117839_EPW import plot_117839_EPW_loss
from plot_117839_EPW import plot_117839_EPW
plot_117839_EPW(data['117839']['117839-9'])
#plot_117839_EPW_loss(data['117839'])

# %%
### PLOT STITCHED 117837-38-39 EPW ###
# %load_ext autoreload
# %autoreload 2
from plot_stitch_117837_8_9 import plot_stitch_117837_38_39_EPW
plot_stitch_117837_38_39_EPW(data)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
