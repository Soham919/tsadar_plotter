# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from TS_aux import select_shots
import pandas as pd
import xarray as xr
from dataclasses import dataclass
from datetime import date
import numpy as np
import matplotlib.pyplot as plt

baseDir = Path().resolve().parent
#folder_path = baseDir/".."/"Kinshock"/"Kinshock-26A"/"tsadar fits"
folder_path = baseDir/".."/"Kinshock"/"Kinshock-19A"/"csv"
data = select_shots(folder_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Stuff in folder :
#
# [0] 92522
#
# [1] 92524
#
# [2] 92525
#
# [3] 92527
#
# [4] 92528
#
# [5] 92530
#
# [6] 92531
#
# [7] 92532
#
# [8] 92533
#
# [9] 92534
#
# [10] 92535
#
# [11] 92536
#
# [12] 92537
#
# [13] 92538
#
# Files for shot 92534 :
#
# [0] 92534-10
# [1] 92534-11
# [2] 92534-4
# [3] 92534_0to400.csv
# [4] 92534_almostfull.csv
# [5] 92534_middle.csv
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Radius (\mum): 68, Wavelength: 1024)
# Coordinates:
#   * Wavelength     (Wavelength) float64 8kB 385.1 385.3 385.6 ... 662.0 662.2
#   * Radius (\mum)  (Radius (\mum)) float64 544B -1e+03 -974.7 ... 651.5 677.2
# Data variables:
#     fit            (Radius (\mum), Wavelength) float64 557kB ...
#     data           (Radius (\mum), Wavelength) float64 557kB ...
# Loaded learned_parameters.csv
# Loaded losses.csv

# %%
### PLOT 117827 ELECTRONS ###
# %reload_ext autoreload
# %autoreload 2
from plot_117827_EPW import plot_117827_EPW_loss
from plot_117827_EPW import plot_117827_EPW
plot_117827_EPW(data['117827']['117827-3'])
#plot_117827_EPW_loss(data['117827'])

# %%
### PLOT 117830 ELECTRONS ###
# %reload_ext autoreload
# %autoreload 2
from plot_117830_EPW import plot_117830_EPW_loss, plot_117830_IAW, plot_117830_EPW
from TS_aux import plot_lineouts

#plot_117830_EPW(data)
plot_117830_IAW(data)
#plot_117830_EPW_loss(data['117830'])
#plot_lineouts(data['117830'])

# %%
### PLOT 117837 ###
# %reload_ext autoreload
# %autoreload 2
from plot_117837_EPW import plot_117837_EPW_loss
from plot_117837_EPW import plot_117837_EPW, plot_117837_IAW
from TS_aux import plot_lineouts
#plot_117837_EPW(data['117837']['117837-13'])
#plot_117837_IAW(data)
#plot_117837_EPW_loss(data['117837'])
plot_lineouts(data['117837'])

# %%
### PLOT 117838 ###
# %reload_ext autoreload
# %autoreload 2
from plot_117838_EPW import plot_117838_EPW_loss
from plot_117838_EPW import plot_117838_EPW, plot_117838_IAW
#plot_117838_EPW(data['117838']['117838-8'])
#plot_117838_IAW(data)
#plot_117838_EPW_loss(data['117838'])
plot_lineouts(data['117838'])

# %%
### PLOT 117839 ###
# %reload_ext autoreload
# %autoreload 2
from plot_117839_EPW import plot_117839_EPW_loss
from plot_117839_EPW import plot_117839_EPW, plot_117839_IAW
#plot_117839_EPW(data['117839']['117839-9'])
plot_117839_IAW(data)
#plot_117839_EPW_loss(data['117839'])

# %%
### PLOT 92534 ELECTRONS ###
from plot_92534_EPW import plot_92534_EPW
plot_92534_EPW(data['92534']['92534-10'])

# %%
### PLOT STITCHED 117837-38-39 EPW ###
# %load_ext autoreload
# %autoreload 2
from plot_stitch_117837_8_9 import plot_stitch_117837_38_39_EPW
plot_stitch_117837_38_39_EPW(data)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
